# %% [markdown]
# Arturo Abisai Marquez Luna  30 de octubre del 2022

# %% [markdown]
# En
# la universidad "ACME" se desea calcular el promedio de cada
# uno de los alumnos, y el área de control escolar genero el archivo
# calificaciones_v2.csv
# para calcular el promedio por alumno, y tener un archivo con formato
# similar al archivo calificaciones_promedio_v2.csv.

# %% [markdown]
# importar librerias

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# verificar las verciones de las mismas

# %%
pd.__version__
# Out:
# '1.5.0'

# %%
np.__version__
# Out:
# '1.23.3'

# %% [markdown]
# leer el archivo usando pd

# %%
calificaciones_v2 = pd.read_csv("calificaciones_v2.csv")

# %%
calificaciones_v2
# Out:
#      matricula  11111111
# 0       nombre  Alumno 1
# 1        grupo      TI11
# 2    Materia 1         1
# 3    Materia 2         8
# 4    Materia 3         1
# ..         ...       ...
# 428  Materia 3        10
# 429  Materia 4         6
# 430  Materia 5         8
# 431  Materia 6        10
# 432     estado   regular
#
# [433 rows x 2 columns]

# %% [markdown]
# los datos repetidos estan en el indice 9,431,106 y 107

# %% [markdown]
# eliminar los datos repetidos por indice

# %%
indices = [7,431,106,107]
calificaciones_v2 = calificaciones_v2.drop(indices,axis=0)

# %%
calificaciones_v2.head(10)
# Out:
#     matricula  11111111
# 0      nombre  Alumno 1
# 1       grupo      TI11
# 2   Materia 1         1
# 3   Materia 2         8
# 4   Materia 3         1
# 5   Materia 4         7
# 6   Materia 5         2
# 8      estado   regular
# 9   matricula  11111112
# 10     nombre  Alumno 2

# %% [markdown]
# formatear index

# %%
calificaciones_v2 = calificaciones_v2.reset_index(drop=True)

# %% [markdown]
# verificar si se formateo el index

# %%
calificaciones_v2.head(9)
# Out:
#    matricula  11111111
# 0     nombre  Alumno 1
# 1      grupo      TI11
# 2  Materia 1         1
# 3  Materia 2         8
# 4  Materia 3         1
# 5  Materia 4         7
# 6  Materia 5         2
# 7     estado   regular
# 8  matricula  11111112

# %%
calificaciones_v2.tail(3) ## muestra segun la cantidad colocada el numero de registros finales
# Out:
#      matricula 11111111
# 426  Materia 4        6
# 427  Materia 5        8
# 428     estado  regular

# %% [markdown]
# separ en partes los dataframe para no afectar datos

# %%
parte_1 = calificaciones_v2.loc[:231,:]
parte_2 = calificaciones_v2.loc[231:,:]

# %% [markdown]
# verificar divicion correcta

# %%
parte_1.head(10)
# Out:
#    matricula  11111111
# 0     nombre  Alumno 1
# 1      grupo      TI11
# 2  Materia 1         1
# 3  Materia 2         8
# 4  Materia 3         1
# 5  Materia 4         7
# 6  Materia 5         2
# 7     estado   regular
# 8  matricula  11111112
# 9     nombre  Alumno 2

# %%
parte_2.tail(3)
# Out:
#      matricula 11111111
# 426  Materia 4        6
# 427  Materia 5        8
# 428     estado  regular

# %% [markdown]
# agregar materia faltante sin afectar los Id

# %%
parte_1.loc[231] = ["Materia 5",0]
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_40648\3524234564.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   parte_1.loc[231] = ["Materia 5",0]

# %% [markdown]
# concatenar los dataframes y formatear id

# %%
partes = [parte_1,parte_2]
calificaciones_v2 = pd.concat(partes, sort=False)

# %%
calificaciones_v2.tail(4)
# Out:
#      matricula 11111111
# 425  Materia 3       10
# 426  Materia 4        6
# 427  Materia 5        8
# 428     estado  regular

# %%
calificaciones_v2=calificaciones_v2.reset_index(drop=True)

# %%
calificaciones_v2
# Out:
#      matricula  11111111
# 0       nombre  Alumno 1
# 1        grupo      TI11
# 2    Materia 1         1
# 3    Materia 2         8
# 4    Materia 3         1
# ..         ...       ...
# 425  Materia 2         4
# 426  Materia 3        10
# 427  Materia 4         6
# 428  Materia 5         8
# 429     estado   regular
#
# [430 rows x 2 columns]

# %% [markdown]
# agregar el estado faltante

# %%
parte_1 = calificaciones_v2.iloc[:322,:]
parte_2 = calificaciones_v2.iloc[322:,:]

# %%
parte_1
# Out:
#      matricula  11111111
# 0       nombre  Alumno 1
# 1        grupo      TI11
# 2    Materia 1         1
# 3    Materia 2         8
# 4    Materia 3         1
# ..         ...       ...
# 317  Materia 1         7
# 318  Materia 2         1
# 319  Materia 3         4
# 320  Materia 4         0
# 321  Materia 5         6
#
# [322 rows x 2 columns]

# %%
parte_1.loc[322] = ["estado","regular"]
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_40648\4035026938.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   parte_1.loc[322] = ["estado","regular"]

# %%
partes = [parte_1,parte_2]
calificaciones_v2 = pd.concat(partes,sort=False)

# %%
calificaciones_v2 = calificaciones_v2.reset_index(drop=True)

# %%
calificaciones_v2
# Out:
#      matricula  11111111
# 0       nombre  Alumno 1
# 1        grupo      TI11
# 2    Materia 1         1
# 3    Materia 2         8
# 4    Materia 3         1
# ..         ...       ...
# 426  Materia 2         4
# 427  Materia 3        10
# 428  Materia 4         6
# 429  Materia 5         8
# 430     estado   regular
#
# [431 rows x 2 columns]

# %% [markdown]
# cambiar todos los campos vacios por 0

# %%
calificaciones_v2 = calificaciones_v2.fillna(0)

# %% [markdown]
# exportar a csv

# %%
calificaciones_v2 = calificaciones_v2.to_csv("calificaciones_vs_datos_completos.csv")

# %% [markdown]
# abrir con numpy

# %%
import csv

# %%
with open("calificaciones_vs_datos_completos.csv") as file:
    calificaciones_v2 = list(csv.reader(file,delimiter=","))

# %%
calificaciones_v2
# Out:
# [['', 'matricula', '11111111'],
#  ['0', 'nombre', 'Alumno 1'],
#  ['1', 'grupo', 'TI11'],
#  ['2', 'Materia 1', '1'],
#  ['3', 'Materia 2', '8'],
#  ['4', 'Materia 3', '1'],
#  ['5', 'Materia 4', '7'],
#  ['6', 'Materia 5', '2'],
#  ['7', 'estado', 'regular'],
#  ['8', 'matricula', '11111112'],
#  ['9', 'nombre', 'Alumno 2'],
#  ['10', 'grupo', 'TI11'],
#  ['11', 'Materia 1', '10'],
#  ['12', 'Materia 2', '7'],
#  ['13', 'Materia 3', '1'],
#  ['14', 'Materia 4', '8'],
#  ['15', 'Materia 5', '5'],
#  ['16', 'estado', 'regular'],
#  ['17', 'matricula', '11111113'],
#  ['18', 'nombre', 'Alumno 3'],
#  ['19', 'grupo', 'TI11'],
#  ['20', 'Materia 1', '0'],
#  ['21', 'Materia 2', '1'],
#  ['22', 'Materia 3', '1'],
#  ['23', 'Materia 4', '3'],
#  ['24', 'Materia 5', '0'],
#  ['25', 'estado', 'regular'],
#  ['26', 'matricula', '11111114'],
#  ['27', 'nombre', 'Alumno 4'],
#  ['28', 'grupo', 'TI11'],
#  ['29', 'Materia 1', '0'],
#  ['30', 'Materia 2', '4'],
#  ['31', 'Materia 3', '3'],
# ...

# %% [markdown]
# pasar a un array de numpy

# %%
calificaciones_v2 = np.array(calificaciones_v2)

# %%
calificaciones_v2
# Out:
# array([['', 'matricula', '11111111'],
#        ['0', 'nombre', 'Alumno 1'],
#        ['1', 'grupo', 'TI11'],
#        ...,
#        ['428', 'Materia 4', '6'],
#        ['429', 'Materia 5', '8'],
#        ['430', 'estado', 'regular']], dtype='<U9')

# %% [markdown]
# eliminar index

# %%
calificaciones_v2 = np.delete(calificaciones_v2,0,1)

# %%
calificaciones_v2
# Out:
# array([['matricula', '11111111'],
#        ['nombre', 'Alumno 1'],
#        ['grupo', 'TI11'],
#        ['Materia 1', '1'],
#        ['Materia 2', '8'],
#        ['Materia 3', '1'],
#        ['Materia 4', '7'],
#        ['Materia 5', '2'],
#        ['estado', 'regular'],
#        ['matricula', '11111112'],
#        ['nombre', 'Alumno 2'],
#        ['grupo', 'TI11'],
#        ['Materia 1', '10'],
#        ['Materia 2', '7'],
#        ['Materia 3', '1'],
#        ['Materia 4', '8'],
#        ['Materia 5', '5'],
#        ['estado', 'regular'],
#        ['matricula', '11111113'],
#        ['nombre', 'Alumno 3'],
#        ['grupo', 'TI11'],
#        ['Materia 1', '0'],
#        ['Materia 2', '1'],
#        ['Materia 3', '1'],
#        ['Materia 4', '3'],
#        ['Materia 5', '0'],
#        ['estado', 'regular'],
#        ['matricula', '11111114'],
#        ['nombre', 'Alumno 4'],
#        ['grupo', 'TI11'],
#        ['Materia 1', '0'],
#        ['Materia 2', '4'],
# ...

# %% [markdown]
# obtener las cabeceras

# %%
cabecera = calificaciones_v2.T[0]

# %%
cabecera
# Out:
# array(['matricula', 'nombre', 'grupo', 'Materia 1', 'Materia 2',
#        'Materia 3', 'Materia 4', 'Materia 5', 'estado', 'matricula',
#        'nombre', 'grupo', 'Materia 1', 'Materia 2', 'Materia 3',
#        'Materia 4', 'Materia 5', 'estado', 'matricula', 'nombre', 'grupo',
#        'Materia 1', 'Materia 2', 'Materia 3', 'Materia 4', 'Materia 5',
#        'estado', 'matricula', 'nombre', 'grupo', 'Materia 1', 'Materia 2',
#        'Materia 3', 'Materia 4', 'Materia 5', 'estado', 'matricula',
#        'nombre', 'grupo', 'Materia 1', 'Materia 2', 'Materia 3',
#        'Materia 4', 'Materia 5', 'estado', 'matricula', 'nombre', 'grupo',
#        'Materia 1', 'Materia 2', 'Materia 3', 'Materia 4', 'Materia 5',
#        'estado', 'matricula', 'nombre', 'grupo', 'Materia 1', 'Materia 2',
#        'Materia 3', 'Materia 4', 'Materia 5', 'estado', 'matricula',
#        'nombre', 'grupo', 'Materia 1', 'Materia 2', 'Materia 3',
# ...

# %%
np.unique(cabecera)
# Out:
# array(['Materia 1', 'Materia 2', 'Materia 3', 'Materia 4', 'Materia 5',
#        'estado', 'grupo', 'matricula', 'nombre'], dtype='<U9')

# %%
np.unique(cabecera).size
# Out:
# 9

# %%
cabecera = cabecera[:9]
cabecera
# Out:
# array(['matricula', 'nombre', 'grupo', 'Materia 1', 'Materia 2',
#        'Materia 3', 'Materia 4', 'Materia 5', 'estado'], dtype='<U9')

# %% [markdown]
# registros

# %%
total_cabecera = cabecera.size

# %%
total_registros = calificaciones_v2.T[0].size

# %%
total = total_registros/total_cabecera
total
# Out:
# 48.0

# %% [markdown]
# eliminar columna de cabecera

# %%
datos = np.delete(calificaciones_v2,0,1)

# %%
datos
# Out:
# array([['11111111'],
#        ['Alumno 1'],
#        ['TI11'],
#        ['1'],
#        ['8'],
#        ['1'],
#        ['7'],
#        ['2'],
#        ['regular'],
#        ['11111112'],
#        ['Alumno 2'],
#        ['TI11'],
#        ['10'],
#        ['7'],
#        ['1'],
#        ['8'],
#        ['5'],
#        ['regular'],
#        ['11111113'],
#        ['Alumno 3'],
#        ['TI11'],
#        ['0'],
#        ['1'],
#        ['1'],
#        ['3'],
#        ['0'],
#        ['regular'],
#        ['11111114'],
#        ['Alumno 4'],
#        ['TI11'],
#        ['0'],
#        ['4'],
#        ['3'],
#        ['2'],
#        ['7'],
#        ['regular'],
#        ['11111115'],
#        ['Alumno 5'],
#        ['TI11'],
#        ['9'],
#        ['10'],
#        ['3'],
#        ['9'],
#        ['2'],
#        ['regular'],
#        ['11111116'],
#        ['Alumno 6'],
#        ['TI11'],
#        ['1'],
#        ['3'],
#        ['8'],
#        ['1'],
#        ['7'],
# ...

# %% [markdown]
# reshape de los datos

# %%
total = int(total)
total_cabecera=int(total_cabecera)

# %%
datos = datos.reshape(total,total_cabecera)

# %%
datos[:15]
# Out:
# array([['11111111', 'Alumno 1', 'TI11', '1', '8', '1', '7', '2',
#         'regular'],
#        ['11111112', 'Alumno 2', 'TI11', '10', '7', '1', '8', '5',
#         'regular'],
#        ['11111113', 'Alumno 3', 'TI11', '0', '1', '1', '3', '0',
#         'regular'],
#        ['11111114', 'Alumno 4', 'TI11', '0', '4', '3', '2', '7',
#         'regular'],
#        ['11111115', 'Alumno 5', 'TI11', '9', '10', '3', '9', '2',
#         'regular'],
#        ['11111116', 'Alumno 6', 'TI11', '1', '3', '8', '1', '7',
#         'regular'],
#        ['11111117', 'Alumno 7', 'TI11', '4', '7', '1', '6', '5',
#         'regular'],
#        ['11111118', 'Alumno 8', 'TI11', '10', '1', '7', '10', '0',
#         'regular'],
#        ['11111119', 'Alumno 9', 'TI11', '5', '5', '4', '0', '3',
#         'regular'],
#        ['11111120', 'Alumno 10', 'TI11', '5', '7', '3', '3', '4',
#         'regular'],
#        ['11111121', 'Alumno 11', 'TI11', '6', '1', '3', '7', '0',
#         'regular'],
# ...

# %% [markdown]
# datos de los alumnos

# %%
info_alumnos = np.array(datos[:,:3])
info_alumnos[:10]
# Out:
# array([['11111111', 'Alumno 1', 'TI11'],
#        ['11111112', 'Alumno 2', 'TI11'],
#        ['11111113', 'Alumno 3', 'TI11'],
#        ['11111114', 'Alumno 4', 'TI11'],
#        ['11111115', 'Alumno 5', 'TI11'],
#        ['11111116', 'Alumno 6', 'TI11'],
#        ['11111117', 'Alumno 7', 'TI11'],
#        ['11111118', 'Alumno 8', 'TI11'],
#        ['11111119', 'Alumno 9', 'TI11'],
#        ['11111120', 'Alumno 10', 'TI11']], dtype='<U9')

# %% [markdown]
# calificaciones de las materias

# %%
materias = np.array(datos[:,3:8],dtype=float)

# %%
materias[:15]
# Out:
# array([[ 1.,  8.,  1.,  7.,  2.],
#        [10.,  7.,  1.,  8.,  5.],
#        [ 0.,  1.,  1.,  3.,  0.],
#        [ 0.,  4.,  3.,  2.,  7.],
#        [ 9., 10.,  3.,  9.,  2.],
#        [ 1.,  3.,  8.,  1.,  7.],
#        [ 4.,  7.,  1.,  6.,  5.],
#        [10.,  1.,  7., 10.,  0.],
#        [ 5.,  5.,  4.,  0.,  3.],
#        [ 5.,  7.,  3.,  3.,  4.],
#        [ 6.,  1.,  3.,  7.,  0.],
#        [ 7.,  2.,  5.,  4.,  5.],
#        [ 5.,  2.,  3.,  0.,  1.],
#        [ 5.,  2., 10.,  0.,  6.],
#        [ 9.,  9.,  1.,  3.,  1.]])

# %%
no_materias = 5
promedios = []
for index in range(int(total)):
    promedios.append(["regular",materias[index].sum()/no_materias])
promedio = np.array(promedios)

# %%
promedios
# Out:
# [['regular', 3.8],
#  ['regular', 6.2],
#  ['regular', 1.0],
#  ['regular', 3.2],
#  ['regular', 6.6],
#  ['regular', 4.0],
#  ['regular', 4.6],
#  ['regular', 5.6],
#  ['regular', 3.4],
#  ['regular', 4.4],
#  ['regular', 3.4],
#  ['regular', 4.6],
#  ['regular', 2.2],
#  ['regular', 4.6],
#  ['regular', 4.6],
#  ['regular', 3.6],
#  ['regular', 1.0],
#  ['regular', 3.6],
#  ['regular', 5.0],
#  ['regular', 2.6],
#  ['regular', 6.4],
#  ['regular', 4.6],
#  ['regular', 6.0],
#  ['regular', 4.2],
#  ['regular', 3.8],
#  ['regular', 2.8],
#  ['regular', 2.2],
#  ['regular', 7.4],
#  ['regular', 3.4],
#  ['regular', 5.8],
#  ['regular', 5.8],
#  ['regular', 3.2],
#  ['regular', 4.2],
#  ['regular', 3.0],
#  ['regular', 6.2],
#  ['regular', 3.6],
#  ['regular', 3.8],
#  ['regular', 4.0],
#  ['regular', 6.2],
#  ['regular', 3.6],
#  ['regular', 5.2],
#  ['regular', 5.0],
#  ['regular', 1.4],
#  ['regular', 4.4],
#  ['regular', 4.2],
#  ['regular', 5.6],
#  ['regular', 6.4],
# ...

# %% [markdown]
# agregar la columna de promedio a las cabeceras

# %%
cabecera = np.concatenate((cabecera,['promedio final']),axis=0,dtype=str)

# %%
cabecera
# Out:
# array(['matricula', 'nombre', 'grupo', 'Materia 1', 'Materia 2',
#        'Materia 3', 'Materia 4', 'Materia 5', 'estado', 'promedio final'],
#       dtype='<U14')

# %% [markdown]
# añadir info del alumno con calificaciones, promedio y estado

# %%
todos = np.concatenate((info_alumnos,materias,promedios),axis=1,dtype=str)
todos[:5]
# Out:
# array([['11111111', 'Alumno 1', 'TI11', '1.0', '8.0', '1.0', '7.0',
#         '2.0', 'regular', '3.8'],
#        ['11111112', 'Alumno 2', 'TI11', '10.0', '7.0', '1.0', '8.0',
#         '5.0', 'regular', '6.2'],
#        ['11111113', 'Alumno 3', 'TI11', '0.0', '1.0', '1.0', '3.0',
#         '0.0', 'regular', '1.0'],
#        ['11111114', 'Alumno 4', 'TI11', '0.0', '4.0', '3.0', '2.0',
#         '7.0', 'regular', '3.2'],
#        ['11111115', 'Alumno 5', 'TI11', '9.0', '10.0', '3.0', '9.0',
#         '2.0', 'regular', '6.6']], dtype='<U32')

# %% [markdown]
# exportar a csv

# %%
todos = pd.DataFrame(data=todos,columns=cabecera,dtype=str)

# %%
todos.head(8)
# Out:
#   matricula    nombre grupo Materia 1 Materia 2 Materia 3 Materia 4 Materia 5  \
# 0  11111111  Alumno 1  TI11       1.0       8.0       1.0       7.0       2.0
# 1  11111112  Alumno 2  TI11      10.0       7.0       1.0       8.0       5.0
# 2  11111113  Alumno 3  TI11       0.0       1.0       1.0       3.0       0.0
# 3  11111114  Alumno 4  TI11       0.0       4.0       3.0       2.0       7.0
# 4  11111115  Alumno 5  TI11       9.0      10.0       3.0       9.0       2.0
# 5  11111116  Alumno 6  TI11       1.0       3.0       8.0       1.0       7.0
# 6  11111117  Alumno 7  TI11       4.0       7.0       1.0       6.0       5.0
# 7  11111118  Alumno 8  TI11      10.0       1.0       7.0      10.0       0.0
#
#     estado promedio final
# 0  regular            3.8
# 1  regular            6.2
# 2  regular            1.0
# 3  regular            3.2
# 4  regular            6.6
# 5  regular            4.0
# 6  regular            4.6
# 7  regular            5.6

# %%
calificaciones_v2_finales = todos.to_csv("calificaciones_v2_finales.csv")
